# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
#检索"text"
text1.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
#索引上下文关联词
text1.similar("monstrous")
# Out:
# imperial subtly impalpable pitiable curious abundant perilous
# trustworthy untoward singular lamentable few determined maddens
# horrible tyrannical lazy mystifying christian exasperate

# %%
text2.similar("monstrous")
# Out:
# very exceedingly so heartily a great good amazingly as sweet
# remarkably extremely vast

# %%
text2.similar("very")
# Out:
# so as too a not monstrous last more was how most exceedingly the only
# first her perfectly cottage will it

# %%
#词语研究
text2.common_contexts(["monstrous","very"])
# Out:
# a_pretty is_pretty a_lucky am_glad be_glad

# %%
#离散图-特定词的频率以及分布绘制
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])
print "\n上图：美国总统就职演说词汇分布图：可以用来研究随时间推移语言使用上的变化。"
# Out:
# 上图：美国总统就职演说词汇分布图：可以用来研究随时间推移语言使用上的变化。

# %%
#词汇计数，包括文本中出现的词和标点符号
len(text3)
# Out:
# 44764

# %%
#词汇表
# set(text3)
sorted(set(text3))
# Out:
# [u'!',
#  u"'",
#  u'(',
#  u')',
#  u',',
#  u',)',
#  u'.',
#  u'.)',
#  u':',
#  u';',
#  u';)',
#  u'?',
#  u'?)',
#  u'A',
#  u'Abel',
#  u'Abelmizraim',
#  u'Abidah',
#  u'Abide',
#  u'Abimael',
#  u'Abimelech',
#  u'Abr',
#  u'Abrah',
#  u'Abraham',
#  u'Abram',
#  u'Accad',
#  u'Achbor',
#  u'Adah',
#  u'Adam',
#  u'Adbeel',
#  u'Admah',
#  u'Adullamite',
#  u'After',
#  u'Aholibamah',
#  u'Ahuzzath',
#  u'Ajah',
#  u'Akan',
#  u'All',
#  u'Allonbachuth',
#  u'Almighty',
#  u'Almodad',
#  u'Also',
#  u'Alvah',
#  u'Alvan',
#  u'Am',
#  u'Amal',
#  u'Amalek',
#  u'Amalekites',
#  u'Ammon',
#  u'Amorite',
#  u'Amorites',
#  u'Amraphel',
#  u'An',
#  u'Anah',
#  u'Anamim',
#  u'And',
#  u'Aner',
#  u'Angel',
#  u'Appoint',
#  u'Aram',
#  u'Aran',
#  u'Ararat',
#  u'Arbah',
#  u'Ard',
#  u'Are',
#  u'Areli',
#  u'Arioch',
#  u'Arise',
#  u'Arkite',
#  u'Arodi',
#  u'Arphaxad',
#  u'Art',
#  u'Arvadite',
#  u'As',
#  u'Asenath',
#  u'Ashbel',
#  u'Asher',
#  u'Ashkenaz',
# ...

# %%
#词汇表长
len(set(text3))
# Out:
# 2789

# %%
#特定词汇计数
text3.count("smote")
# Out:
# 5

# %%
#计算一个特定的词在文本中占据的百分比
100.0 * text4.count("a") / len(text4)
# Out:
# 1.4643016433938312

# %%
ex1 = ['Monty', 'Python', 'and', 'the', 'Holy', 'Grail', 'Grail']
print "sorted(ex1)",sorted(ex1)

print "len(ex1)",len(ex1)

print "len(set(ex1))",len(set(ex1))

print "ex1.count('Grail')", ex1.count('Grail')

#增加元素，链接
ex2 = ['pisunk']
ex1.append("okey")
print "ex1+ex2", ex1+ex2
print "ex1", ex1
# Out:
# sorted(ex1) ['Grail', 'Grail', 'Holy', 'Monty', 'Python', 'and', 'the']
# len(ex1) 7
# len(set(ex1)) 6
# ex1.count('Grail') 2
# ex1+ex2 ['Monty', 'Python', 'and', 'the', 'Holy', 'Grail', 'Grail', 'okey', 'pisunk']
# ex1 ['Monty', 'Python', 'and', 'the', 'Holy', 'Grail', 'Grail', 'okey']

# %%
#索引某个词汇,索引从零开始
text3.index('smote')
# Out:
# 9073

# %%
text3[9073]
# Out:
# u'smote'

# %%
text3[9073:9075]
# Out:
# [u'smote', u'the']

# %%
text3[0]
# Out:
# u'In'

# %%
#ex1 ['Monty', 'Python', 'and', 'the', 'Holy', 'Grail', 'Grail', 'okey'], m:n 表示元素m…n-1
ex1[1:3]
# Out:
# ['Python', 'and']

# %%
# ex1[0]='my_start'
# ex1[7]='my_end'
# len(ex1)
# print "ex1_ch1", ex1
# ex1[1:7]=["woo1",'woo2']
# print "ex1_ch2", ex1

# %%
#排序表中大写字母出现在小写字母之前
#字符串
name = ['Month','Year']
print 'name[0][0]', name[0][0]
print 'name[0][0:3]', name[0][0:3]
# Out:
# name[0][0] M
# name[0][0:3] Mon

# %%
print 'name * 2', name * 2
name2 = "month"
print 'name2 + ?? is', name2 + '?'
' '.join(['ss','aa'])
# Out:
# name * 2 ['Month', 'Year', 'Month', 'Year']
# name2 + ?? is month?
# 'ss aa'

# %%
'pp yy'.split()
# Out:
# ['pp', 'yy']

# %%
#词频分布 FreqDist 
fdist1 = FreqDist(text1)
print fdist1
fdist1.most_common(50)
# Out:
# <FreqDist with 19317 samples and 260819 outcomes>
# [(u',', 18713),
#  (u'the', 13721),
#  (u'.', 6862),
#  (u'of', 6536),
#  (u'and', 6024),
#  (u'a', 4569),
#  (u'to', 4542),
#  (u';', 4072),
#  (u'in', 3916),
#  (u'that', 2982),
#  (u"'", 2684),
#  (u'-', 2552),
#  (u'his', 2459),
#  (u'it', 2209),
#  (u'I', 2124),
#  (u's', 1739),
#  (u'is', 1695),
#  (u'he', 1661),
#  (u'with', 1659),
#  (u'was', 1632),
#  (u'as', 1620),
#  (u'"', 1478),
#  (u'all', 1462),
#  (u'for', 1414),
#  (u'this', 1280),
#  (u'!', 1269),
#  (u'at', 1231),
#  (u'by', 1137),
#  (u'but', 1113),
#  (u'not', 1103),
#  (u'--', 1070),
#  (u'him', 1058),
#  (u'from', 1052),
#  (u'be', 1030),
#  (u'on', 1005),
#  (u'so', 918),
#  (u'whale', 906),
#  (u'one', 889),
#  (u'you', 841),
#  (u'had', 767),
#  (u'have', 760),
#  (u'there', 715),
#  (u'But', 705),
#  (u'or', 697),
#  (u'were', 680),
#  (u'now', 646),
#  (u'which', 640),
#  (u'?', 637),
#  (u'me', 627),
#  (u'like', 624)]

# %%
fdist1['whale']
# Out:
# 906

# %%
fdist1.plot(50,cumulative=True)

# %%
#选择词
V = set(text1)
long_words = [w for w in V if len(w) > 15]#选长度大于15
sorted(long_words)
# Out:
# [u'CIRCUMNAVIGATION',
#  u'Physiognomically',
#  u'apprehensiveness',
#  u'cannibalistically',
#  u'characteristically',
#  u'circumnavigating',
#  u'circumnavigation',
#  u'circumnavigations',
#  u'comprehensiveness',
#  u'hermaphroditical',
#  u'indiscriminately',
#  u'indispensableness',
#  u'irresistibleness',
#  u'physiognomically',
#  u'preternaturalness',
#  u'responsibilities',
#  u'simultaneousness',
#  u'subterraneousness',
#  u'supernaturalness',
#  u'superstitiousness',
#  u'uncomfortableness',
#  u'uncompromisedness',
#  u'undiscriminating',
#  u'uninterpenetratingly']

# %%
fdist5 = FreqDist(text5)
sorted(w for w in set(text5) if len(w) > 7 and fdist5[w] > 7)#text5中，len(w) > 7 保证词长都超过七个字母，fdist5[w] > 7 保证这些词出现超过7 次
# Out:
# [u'#14-19teens',
#  u'#talkcity_adults',
#  u'((((((((((',
#  u'........',
#  u'Question',
#  u'actually',
#  u'anything',
#  u'computer',
#  u'cute.-ass',
#  u'everyone',
#  u'football',
#  u'innocent',
#  u'listening',
#  u'remember',
#  u'seriously',
#  u'something',
#  u'together',
#  u'tomorrow',
#  u'watching']

# %%
#连词
text4.collocations()
# Out:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; Old
# World; Almighty God; Fellow citizens; Chief Magistrate; Chief Justice;
# God bless; every citizen; Indian tribes; public debt; one another;
# foreign nations; political parties

# %%
list(bigrams(['more', 'is', 'said', 'than', 'done']))
# Out:
# [('more', 'is'), ('is', 'said'), ('said', 'than'), ('than', 'done')]

# %%
#计数词长
[len(w) for w in text1]
# Out:
# [1,
#  4,
#  4,
#  2,
#  6,
#  8,
#  4,
#  1,
#  9,
#  1,
#  1,
#  8,
#  2,
#  1,
#  4,
#  11,
#  5,
#  2,
#  1,
#  7,
#  6,
#  1,
#  3,
#  4,
#  5,
#  2,
#  10,
#  2,
#  4,
#  1,
#  5,
#  1,
#  4,
#  1,
#  3,
#  5,
#  1,
#  1,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  4,
#  7,
#  3,
#  3,
#  8,
#  3,
#  8,
#  1,
#  4,
#  1,
#  5,
#  12,
#  1,
#  9,
#  11,
#  4,
#  3,
#  3,
#  3,
#  5,
#  2,
#  3,
#  3,
#  5,
#  7,
#  2,
#  3,
#  5,
#  1,
#  2,
#  5,
#  2,
#  4,
#  3,
#  3,
#  8,
#  1,
#  2,
#  7,
#  6,
#  8,
#  3,
#  2,
#  3,
#  9,
#  1,
#  1,
#  5,
#  3,
#  4,
#  2,
#  4,
#  2,
#  6,
#  6,
#  1,
#  3,
#  2,
#  5,
#  4,
#  2,
#  4,
#  4,
#  1,
#  5,
#  1,
#  4,
#  2,
#  2,
#  2,
#  6,
#  2,
#  3,
#  6,
#  7,
#  3,
#  1,
#  7,
#  9,
#  1,
#  3,
#  6,
#  1,
#  1,
#  5,
#  6,
#  5,
#  6,
#  3,
#  13,
#  2,
#  3,
#  4,
#  1,
#  3,
#  7,
#  4,
#  5,
#  2,
#  3,
#  4,
#  2,
#  2,
#  8,
#  1,
#  5,
#  1,
#  3,
#  2,
#  1,
#  3,
#  3,
#  1,
#  4,
#  1,
#  4,
#  6,
#  2,
#  5,
#  4,
#  9,
# ...

# %%
#不同长度词的freq
fdist = FreqDist(len(w) for w in text1)
print fdist
fdist
# Out:
# <FreqDist with 19 samples and 260819 outcomes>
# FreqDist({1: 47933,
#           2: 38513,
#           3: 50223,
#           4: 42345,
#           5: 26597,
#           6: 17111,
#           7: 14399,
#           8: 9966,
#           9: 6428,
#           10: 3528,
#           11: 1873,
#           12: 1053,
#           13: 567,
#           14: 177,
#           15: 70,
#           16: 22,
#           17: 12,
#           18: 1,
#           20: 1})

# %%
fdist.most_common()
# Out:
# [(3, 50223),
#  (1, 47933),
#  (4, 42345),
#  (2, 38513),
#  (5, 26597),
#  (6, 17111),
#  (7, 14399),
#  (8, 9966),
#  (9, 6428),
#  (10, 3528),
#  (11, 1873),
#  (12, 1053),
#  (13, 567),
#  (14, 177),
#  (15, 70),
#  (16, 22),
#  (17, 12),
#  (18, 1),
#  (20, 1)]

# %%
fdist.max()
# Out:
# 3

# %%
fdist.freq(3)
# Out:
# 0.19255882431878046

# %%
#所有这些例子都有一个共同的模式：[w for w in text if condition ]
sent1 = ['Call', 'me', 'Ishmael', '.']
for xx in sent1:
    if xx.endswith('l'):
        print xx
# Out:
# Call
# Ishmael

# %% [markdown]
# 比如：知识图谱的应用：语义、句子成分
#
# 哈工大语料
#
# pytorch
#
# 方向：语料 分词 词性标注 文本分类（主题模型，cnn，lstm） 文本信息提取 机器翻译、机器问答
#
# 基于tf pt的项目
